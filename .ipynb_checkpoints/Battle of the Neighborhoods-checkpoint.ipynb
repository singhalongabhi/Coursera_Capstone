# %% [markdown]
# ## Problem Description

# %% [markdown]
# Given the advent of shared workspaces, I believe it is a good idea to research the perfect location of setting up a shared workspace in Philadelphia. Given that Philadelphia is home to a lot on educational institutions and students are always coming up with great ideas that can be the next big thing. One of the examples is GoPuff which recently received a major investment from Softbank.
#
# This analysis can be used by either people who are looking to jump into the investement for a shared workspace or pre established companies like WeWork who are looking for expansion into cities.
#
#
# To start, Firstly, A perfect shared workspace would be a place which is near the educational institutions allowing student contributors to come and go easily and even at odd hours, given that the startups and small team companies have a varied working schedule for hours.
#
# Secondly the workspace should be adequetly be accesible by public transport systems, so bus or train stations will also be measured in.
#
# Another factor to measure is the availability of restaurants and other food joints and also making sure that they are open at the odd hours in case the companies want to work in late and order food.
#
# The plan is to start with these basic parameters and then see if we can measure in other factors to enhance the search for a perfect shared workspace in Philadelphia.
#
# Let the search begin!

# %% [markdown]
# ## Data

# %% [markdown]
# The data we will be using will be Foursquare location data to track proximity to institutions, public transport hotspots and restaurants / eateries etc. for the city of Philadelphia. Also, We will be making use of the following packages that are imported in the cell below. These are basically used for getting location data, address information, clustering library and matplotlib and folium for plotting modules and map rendering respectively.

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import pandas as pd
import numpy as np
# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # map rendering library
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.

# %%
pip install pgeocode
# Out:
# Requirement already satisfied: pgeocode in /Users/abhimanyusingh/anaconda3/lib/python3.8/site-packages (0.2.1)
# Requirement already satisfied: numpy in /Users/abhimanyusingh/anaconda3/lib/python3.8/site-packages (from pgeocode) (1.18.5)
# Requirement already satisfied: pandas in /Users/abhimanyusingh/anaconda3/lib/python3.8/site-packages (from pgeocode) (1.0.5)
# Requirement already satisfied: requests in /Users/abhimanyusingh/anaconda3/lib/python3.8/site-packages (from pgeocode) (2.24.0)
# Requirement already satisfied: pytz>=2017.2 in /Users/abhimanyusingh/anaconda3/lib/python3.8/site-packages (from pandas->pgeocode) (2020.1)
# Requirement already satisfied: python-dateutil>=2.6.1 in /Users/abhimanyusingh/anaconda3/lib/python3.8/site-packages (from pandas->pgeocode) (2.8.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/abhimanyusingh/anaconda3/lib/python3.8/site-packages (from requests->pgeocode) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in /Users/abhimanyusingh/anaconda3/lib/python3.8/site-packages (from requests->pgeocode) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /Users/abhimanyusingh/anaconda3/lib/python3.8/site-packages (from requests->pgeocode) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/abhimanyusingh/anaconda3/lib/python3.8/site-packages (from requests->pgeocode) (1.25.9)
# Requirement already satisfied: six>=1.5 in /Users/abhimanyusingh/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.6.1->pandas->pgeocode) (1.15.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Geolocator to get location Coordinates for Philadelphia

# %%
address = 'Philadelphia, US'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Philadelphia are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Philadelphia are 39.9527237, -75.1635262.

# %% [markdown]
# ## Pgeocode to get the latitudes and longitudes for various neighborhoods for Philadelphia and also ease of calculating distances between lat,long duos

# %%
import pgeocode
nomi = pgeocode.Nominatim('us')
zips = ["19102","19103","19104","19106","19107","19109","19111","19112","19114","19115","19116","19118","19119","19120","19121","19122","19123","19124","19125","19126","19127","19128","19129","19130","19131","19132","19133","19134","19135","19136","19137","19138","19139","19140","19141","19142","19143","19144","19145","19146","19147","19148","19149","19150","19151","19152","19153","19154"]
phillyData = nomi.query_postal_code(zips)
phillyData
# Out:
#    postal_code country code    place_name    state_name state_code  \
# 0        19102           US  Philadelphia  Pennsylvania         PA
# 1        19103           US  Philadelphia  Pennsylvania         PA
# 2        19104           US  Philadelphia  Pennsylvania         PA
# 3        19106           US  Philadelphia  Pennsylvania         PA
# 4        19107           US  Philadelphia  Pennsylvania         PA
# 5        19109           US  Philadelphia  Pennsylvania         PA
# 6        19111           US  Philadelphia  Pennsylvania         PA
# 7        19112           US  Philadelphia  Pennsylvania         PA
# 8        19114           US  Philadelphia  Pennsylvania         PA
# 9        19115           US  Philadelphia  Pennsylvania         PA
# 10       19116           US  Philadelphia  Pennsylvania         PA
# 11       19118           US  Philadelphia  Pennsylvania         PA
# 12       19119           US  Philadelphia  Pennsylvania         PA
# 13       19120           US  Philadelphia  Pennsylvania         PA
# 14       19121           US  Philadelphia  Pennsylvania         PA
# 15       19122           US  Philadelphia  Pennsylvania         PA
# 16       19123           US  Philadelphia  Pennsylvania         PA
# 17       19124           US  Philadelphia  Pennsylvania         PA
# 18       19125           US  Philadelphia  Pennsylvania         PA
# 19       19126           US  Philadelphia  Pennsylvania         PA
# 20       19127           US  Philadelphia  Pennsylvania         PA
# 21       19128           US  Philadelphia  Pennsylvania         PA
# 22       19129           US  Philadelphia  Pennsylvania         PA
# 23       19130           US  Philadelphia  Pennsylvania         PA
# 24       19131           US  Philadelphia  Pennsylvania         PA
# 25       19132           US  Philadelphia  Pennsylvania         PA
# 26       19133           US  Philadelphia  Pennsylvania         PA
# 27       19134           US  Philadelphia  Pennsylvania         PA
# 28       19135           US  Philadelphia  Pennsylvania         PA
# 29       19136           US  Philadelphia  Pennsylvania         PA
# 30       19137           US  Philadelphia  Pennsylvania         PA
# 31       19138           US  Philadelphia  Pennsylvania         PA
# 32       19139           US  Philadelphia  Pennsylvania         PA
# 33       19140           US  Philadelphia  Pennsylvania         PA
# 34       19141           US  Philadelphia  Pennsylvania         PA
# 35       19142           US  Philadelphia  Pennsylvania         PA
# 36       19143           US  Philadelphia  Pennsylvania         PA
# 37       19144           US  Philadelphia  Pennsylvania         PA
# 38       19145           US  Philadelphia  Pennsylvania         PA
# 39       19146           US  Philadelphia  Pennsylvania         PA
# 40       19147           US  Philadelphia  Pennsylvania         PA
# 41       19148           US  Philadelphia  Pennsylvania         PA
# 42       19149           US  Philadelphia  Pennsylvania         PA
# 43       19150           US  Philadelphia  Pennsylvania         PA
# 44       19151           US  Philadelphia  Pennsylvania         PA
# 45       19152           US  Philadelphia  Pennsylvania         PA
# 46       19153           US  Philadelphia  Pennsylvania         PA
# 47       19154           US  Philadelphia  Pennsylvania         PA
#
#      county_name  county_code community_name  community_code  latitude  \
# 0   Philadelphia        101.0            NaN             NaN   39.9489
# 1   Philadelphia        101.0            NaN             NaN   39.9513
# 2   Philadelphia        101.0            NaN             NaN   39.9597
# 3   Philadelphia        101.0            NaN             NaN   39.9474
# 4   Philadelphia        101.0            NaN             NaN   39.9487
# 5   Philadelphia        101.0            NaN             NaN   39.9496
# 6   Philadelphia        101.0            NaN             NaN   40.0596
# 7   Philadelphia        101.0            NaN             NaN   39.8893
# 8   Philadelphia        101.0            NaN             NaN   40.0634
# 9   Philadelphia        101.0            NaN             NaN   40.0903
# 10  Philadelphia        101.0            NaN             NaN   40.1166
# 11  Philadelphia        101.0            NaN             NaN   40.0723
# 12  Philadelphia        101.0            NaN             NaN   40.0547
# 13  Philadelphia        101.0            NaN             NaN   40.0343
# 14  Philadelphia        101.0            NaN             NaN   39.9811
# 15  Philadelphia        101.0            NaN             NaN   39.9780
# 16  Philadelphia        101.0            NaN             NaN   39.9660
# 17  Philadelphia        101.0            NaN             NaN   40.0178
# 18  Philadelphia        101.0            NaN             NaN   39.9788
# 19    Montgomery         91.0            NaN             NaN   40.0568
# 20  Philadelphia        101.0            NaN             NaN   40.0275
# 21  Philadelphia        101.0            NaN             NaN   40.0402
# 22  Philadelphia        101.0            NaN             NaN   40.0118
# 23  Philadelphia        101.0            NaN             NaN   39.9677
# 24  Philadelphia        101.0            NaN             NaN   39.9845
# 25  Philadelphia        101.0            NaN             NaN   39.9954
# 26  Philadelphia        101.0            NaN             NaN   39.9925
# 27  Philadelphia        101.0            NaN             NaN   39.9925
# 28  Philadelphia        101.0            NaN             NaN   40.0247
# 29  Philadelphia        101.0            NaN             NaN   40.0422
# 30  Philadelphia        101.0            NaN             NaN   40.0008
# 31  Philadelphia        101.0            NaN             NaN   40.0568
# 32  Philadelphia        101.0            NaN             NaN   39.9612
# 33  Philadelphia        101.0            NaN             NaN   40.0118
# 34  Philadelphia        101.0            NaN             NaN   40.0365
# 35  Philadelphia        101.0            NaN             NaN   39.9223
# 36  Philadelphia        101.0            NaN             NaN   39.9448
# 37  Philadelphia        101.0            NaN             NaN   40.0338
# 38  Philadelphia        101.0            NaN             NaN   39.9227
# 39  Philadelphia        101.0            NaN             NaN   39.9379
# 40  Philadelphia        101.0            NaN             NaN   39.9362
# 41  Philadelphia        101.0            NaN             NaN   39.9207
# 42  Philadelphia        101.0            NaN             NaN   40.0369
# 43  Philadelphia        101.0            NaN             NaN   40.0726
# 44  Philadelphia        101.0            NaN             NaN   39.9772
# 45  Philadelphia        101.0            NaN             NaN   40.0606
# 46  Philadelphia        101.0            NaN             NaN   39.9055
# 47  Philadelphia        101.0            NaN             NaN   40.0897
#
#     longitude  accuracy
# 0    -75.1661       4.0
# 1    -75.1741       4.0
# 2    -75.2024       4.0
# 3    -75.1473       4.0
# 4    -75.1593       4.0
# 5    -75.1637       4.0
# 6    -75.0818       4.0
# 7    -75.1782       4.0
# 8    -74.9990       4.0
# 9    -75.0410       4.0
# 10   -75.0198       4.0
# 11   -75.2034       4.0
# 12   -75.1866       4.0
# 13   -75.1213       4.0
# 14   -75.1740       4.0
# 15   -75.1459       4.0
# 16   -75.1510       4.0
# 17   -75.0895       4.0
# 18   -75.1262       4.0
# 19   -75.1379       4.0
# 20   -75.2242       4.0
# 21   -75.2231       4.0
# 22   -75.1861       4.0
# 23   -75.1735       4.0
# 24   -75.2282       4.0
# 25   -75.1698       4.0
# 26   -75.1415       4.0
# 27   -75.1133       4.0
# 28   -75.0518       4.0
# 29   -75.0244       4.0
# 30   -75.0727       4.0
# 31   -75.1569       4.0
# 32   -75.2303       4.0
# 33   -75.1456       4.0
# 34   -75.1451       4.0
# 35   -75.2338       4.0
# 36   -75.2288       4.0
# 37   -75.1731       4.0
# 38   -75.1812       4.0
# 39   -75.1794       4.0
# 40   -75.1563       4.0
# 41   -75.1595       4.0
# 42   -75.0664       4.0
# 43   -75.1706       4.0
# 44   -75.2545       4.0
# 45   -75.0471       4.0
# 46   -75.2444       4.0
# 47   -74.9781       4.0

# %% [markdown]
# ## Reverse locator to get Neighborhood names, since Pgeocode is missing those

# %%
locator = Nominatim(user_agent="myGeocoder")
coordinates = "40.0568,-75.1379"
location = locator.reverse(coordinates)
location.raw
# Out:
# {'place_id': 265010142,
#  'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#  'osm_type': 'way',
#  'osm_id': 12204094,
#  'lat': '40.056403857142854',
#  'lon': '-75.13793804081634',
#  'display_name': '1255, 68th Avenue, Pittville, Philadelphia, Philadelphia County, Pennsylvania, 19126, United States of America',
#  'address': {'house_number': '1255',
#   'road': '68th Avenue',
#   'neighbourhood': 'Pittville',
#   'city': 'Philadelphia',
#   'county': 'Philadelphia County',
#   'state': 'Pennsylvania',
#   'postcode': '19126',
#   'country': 'United States of America',
#   'country_code': 'us'},
#  'boundingbox': ['40.056353857143',
#   '40.056453857143',
#   '-75.137988040816',
#   '-75.137888040816']}

# %% [markdown]
# ## Data Prep and Cleaning

# %%
#Appending Neighbourhood/Suburb Names

for index, row in phillyData.iterrows():
    lat = row['latitude']
    lon = row['longitude']
    coords = str(lat)+','+str(lon)
    location = locator.reverse(coords)
#     print("\n")
#     print(location.raw)
    try:
        neighbourhood = location.raw['address']['neighbourhood']
    except Exception as e:
        print("Neighbourhood doesn't exist, checking for Suburb")
        try:
            neighbourhood = location.raw['address']['suburb']
        except Exception as e:
            print("No Neighbourhood, No Suburb")
            neighbourhood = ''
    phillyData.at[index,'neighbourhood'] = neighbourhood
    
phillyData
# Out:
# Neighbourhood doesn't exist, checking for Suburb
# Neighbourhood doesn't exist, checking for Suburb
# No Neighbourhood, No Suburb
# Neighbourhood doesn't exist, checking for Suburb
#    postal_code country code    place_name    state_name state_code  \
# 0        19102           US  Philadelphia  Pennsylvania         PA
# 1        19103           US  Philadelphia  Pennsylvania         PA
# 2        19104           US  Philadelphia  Pennsylvania         PA
# 3        19106           US  Philadelphia  Pennsylvania         PA
# 4        19107           US  Philadelphia  Pennsylvania         PA
# 5        19109           US  Philadelphia  Pennsylvania         PA
# 6        19111           US  Philadelphia  Pennsylvania         PA
# 7        19112           US  Philadelphia  Pennsylvania         PA
# 8        19114           US  Philadelphia  Pennsylvania         PA
# 9        19115           US  Philadelphia  Pennsylvania         PA
# 10       19116           US  Philadelphia  Pennsylvania         PA
# 11       19118           US  Philadelphia  Pennsylvania         PA
# 12       19119           US  Philadelphia  Pennsylvania         PA
# 13       19120           US  Philadelphia  Pennsylvania         PA
# 14       19121           US  Philadelphia  Pennsylvania         PA
# 15       19122           US  Philadelphia  Pennsylvania         PA
# 16       19123           US  Philadelphia  Pennsylvania         PA
# 17       19124           US  Philadelphia  Pennsylvania         PA
# 18       19125           US  Philadelphia  Pennsylvania         PA
# 19       19126           US  Philadelphia  Pennsylvania         PA
# 20       19127           US  Philadelphia  Pennsylvania         PA
# 21       19128           US  Philadelphia  Pennsylvania         PA
# 22       19129           US  Philadelphia  Pennsylvania         PA
# 23       19130           US  Philadelphia  Pennsylvania         PA
# 24       19131           US  Philadelphia  Pennsylvania         PA
# 25       19132           US  Philadelphia  Pennsylvania         PA
# 26       19133           US  Philadelphia  Pennsylvania         PA
# 27       19134           US  Philadelphia  Pennsylvania         PA
# 28       19135           US  Philadelphia  Pennsylvania         PA
# 29       19136           US  Philadelphia  Pennsylvania         PA
# 30       19137           US  Philadelphia  Pennsylvania         PA
# 31       19138           US  Philadelphia  Pennsylvania         PA
# 32       19139           US  Philadelphia  Pennsylvania         PA
# 33       19140           US  Philadelphia  Pennsylvania         PA
# 34       19141           US  Philadelphia  Pennsylvania         PA
# 35       19142           US  Philadelphia  Pennsylvania         PA
# 36       19143           US  Philadelphia  Pennsylvania         PA
# 37       19144           US  Philadelphia  Pennsylvania         PA
# 38       19145           US  Philadelphia  Pennsylvania         PA
# 39       19146           US  Philadelphia  Pennsylvania         PA
# 40       19147           US  Philadelphia  Pennsylvania         PA
# 41       19148           US  Philadelphia  Pennsylvania         PA
# 42       19149           US  Philadelphia  Pennsylvania         PA
# 43       19150           US  Philadelphia  Pennsylvania         PA
# 44       19151           US  Philadelphia  Pennsylvania         PA
# 45       19152           US  Philadelphia  Pennsylvania         PA
# 46       19153           US  Philadelphia  Pennsylvania         PA
# 47       19154           US  Philadelphia  Pennsylvania         PA
#
#      county_name  county_code community_name  community_code  latitude  \
# 0   Philadelphia        101.0            NaN             NaN   39.9489
# 1   Philadelphia        101.0            NaN             NaN   39.9513
# 2   Philadelphia        101.0            NaN             NaN   39.9597
# 3   Philadelphia        101.0            NaN             NaN   39.9474
# 4   Philadelphia        101.0            NaN             NaN   39.9487
# 5   Philadelphia        101.0            NaN             NaN   39.9496
# 6   Philadelphia        101.0            NaN             NaN   40.0596
# 7   Philadelphia        101.0            NaN             NaN   39.8893
# 8   Philadelphia        101.0            NaN             NaN   40.0634
# 9   Philadelphia        101.0            NaN             NaN   40.0903
# 10  Philadelphia        101.0            NaN             NaN   40.1166
# 11  Philadelphia        101.0            NaN             NaN   40.0723
# 12  Philadelphia        101.0            NaN             NaN   40.0547
# 13  Philadelphia        101.0            NaN             NaN   40.0343
# 14  Philadelphia        101.0            NaN             NaN   39.9811
# 15  Philadelphia        101.0            NaN             NaN   39.9780
# 16  Philadelphia        101.0            NaN             NaN   39.9660
# 17  Philadelphia        101.0            NaN             NaN   40.0178
# 18  Philadelphia        101.0            NaN             NaN   39.9788
# 19    Montgomery         91.0            NaN             NaN   40.0568
# 20  Philadelphia        101.0            NaN             NaN   40.0275
# 21  Philadelphia        101.0            NaN             NaN   40.0402
# 22  Philadelphia        101.0            NaN             NaN   40.0118
# 23  Philadelphia        101.0            NaN             NaN   39.9677
# 24  Philadelphia        101.0            NaN             NaN   39.9845
# 25  Philadelphia        101.0            NaN             NaN   39.9954
# 26  Philadelphia        101.0            NaN             NaN   39.9925
# 27  Philadelphia        101.0            NaN             NaN   39.9925
# 28  Philadelphia        101.0            NaN             NaN   40.0247
# 29  Philadelphia        101.0            NaN             NaN   40.0422
# 30  Philadelphia        101.0            NaN             NaN   40.0008
# 31  Philadelphia        101.0            NaN             NaN   40.0568
# 32  Philadelphia        101.0            NaN             NaN   39.9612
# 33  Philadelphia        101.0            NaN             NaN   40.0118
# 34  Philadelphia        101.0            NaN             NaN   40.0365
# 35  Philadelphia        101.0            NaN             NaN   39.9223
# 36  Philadelphia        101.0            NaN             NaN   39.9448
# 37  Philadelphia        101.0            NaN             NaN   40.0338
# 38  Philadelphia        101.0            NaN             NaN   39.9227
# 39  Philadelphia        101.0            NaN             NaN   39.9379
# 40  Philadelphia        101.0            NaN             NaN   39.9362
# 41  Philadelphia        101.0            NaN             NaN   39.9207
# 42  Philadelphia        101.0            NaN             NaN   40.0369
# 43  Philadelphia        101.0            NaN             NaN   40.0726
# 44  Philadelphia        101.0            NaN             NaN   39.9772
# 45  Philadelphia        101.0            NaN             NaN   40.0606
# 46  Philadelphia        101.0            NaN             NaN   39.9055
# 47  Philadelphia        101.0            NaN             NaN   40.0897
#
#     longitude  accuracy                      neighbourhood
# 0    -75.1661       4.0                 Rittenhouse Square
# 1    -75.1741       4.0                 Rittenhouse Square
# 2    -75.2024       4.0                   Powelton Village
# 3    -75.1473       4.0                       Society Hill
# 4    -75.1593       4.0                 Rittenhouse Square
# 5    -75.1637       4.0                 Rittenhouse Square
# 6    -75.0818       4.0                           Burholme
# 7    -75.1782       4.0                 South Philadelphia
# 8    -74.9990       4.0                     Academy Garden
# 9    -75.0410       4.0                          Pauls Run
# 10   -75.0198       4.0                           Somerton
# 11   -75.2034       4.0                            Gravers
# 12   -75.1866       4.0                     Mount Pleasant
# 13   -75.1213       4.0                              Olney
# 14   -75.1740       4.0
# 15   -75.1459       4.0                             Ludlow
# 16   -75.1510       4.0                             Poplar
# 17   -75.0895       4.0                          Northwood
# 18   -75.1262       4.0                           Fishtown
# 19   -75.1379       4.0                          Pittville
# 20   -75.2242       4.0                        Glen Willow
# 21   -75.2231       4.0                         Roxborough
# 22   -75.1861       4.0                         East Falls
# 23   -75.1735       4.0                      Spring Garden
# 24   -75.2282       4.0                           Parkside
# 25   -75.1698       4.0                            Stanton
# 26   -75.1415       4.0                    West Kensington
# 27   -75.1133       4.0  Port Richmond Polish Neighborhood
# 28   -75.0518       4.0                        Wissinoming
# 29   -75.0244       4.0                         Holmesburg
# 30   -75.0727       4.0                         Bridesburg
# 31   -75.1569       4.0                         Somerville
# 32   -75.2303       4.0                       Garden Court
# 33   -75.1456       4.0                       Hunting Park
# 34   -75.1451       4.0                              Tabor
# 35   -75.2338       4.0                           Paschall
# 36   -75.2288       4.0                         Cedar Park
# 37   -75.1731       4.0                     Wayne Junction
# 38   -75.1812       4.0                     Girard Estates
# 39   -75.1794       4.0                          Hawthorne
# 40   -75.1563       4.0                        Bella Vista
# 41   -75.1595       4.0                 South Philadelphia
# 42   -75.0664       4.0                        Wissinoming
# 43   -75.1706       4.0                            Mermaid
# 44   -75.2545       4.0                          Overbrook
# 45   -75.0471       4.0                     Pennypack Park
# 46   -75.2444       4.0                           Eastwick
# 47   -74.9781       4.0                     Longmead Farms

# %%
#Dropping non essential columns 

phillyData = phillyData[['postal_code','county_name','latitude', 'longitude', 'neighbourhood']]

#Dropping empty neighbourhood rows

phillyData = phillyData[phillyData['neighbourhood'] != '']

phillyData
# Out:
#    postal_code   county_name  latitude  longitude  \
# 0        19102  Philadelphia   39.9489   -75.1661
# 1        19103  Philadelphia   39.9513   -75.1741
# 2        19104  Philadelphia   39.9597   -75.2024
# 3        19106  Philadelphia   39.9474   -75.1473
# 4        19107  Philadelphia   39.9487   -75.1593
# 5        19109  Philadelphia   39.9496   -75.1637
# 6        19111  Philadelphia   40.0596   -75.0818
# 7        19112  Philadelphia   39.8893   -75.1782
# 8        19114  Philadelphia   40.0634   -74.9990
# 9        19115  Philadelphia   40.0903   -75.0410
# 10       19116  Philadelphia   40.1166   -75.0198
# 11       19118  Philadelphia   40.0723   -75.2034
# 12       19119  Philadelphia   40.0547   -75.1866
# 13       19120  Philadelphia   40.0343   -75.1213
# 15       19122  Philadelphia   39.9780   -75.1459
# 16       19123  Philadelphia   39.9660   -75.1510
# 17       19124  Philadelphia   40.0178   -75.0895
# 18       19125  Philadelphia   39.9788   -75.1262
# 19       19126    Montgomery   40.0568   -75.1379
# 20       19127  Philadelphia   40.0275   -75.2242
# 21       19128  Philadelphia   40.0402   -75.2231
# 22       19129  Philadelphia   40.0118   -75.1861
# 23       19130  Philadelphia   39.9677   -75.1735
# 24       19131  Philadelphia   39.9845   -75.2282
# 25       19132  Philadelphia   39.9954   -75.1698
# 26       19133  Philadelphia   39.9925   -75.1415
# 27       19134  Philadelphia   39.9925   -75.1133
# 28       19135  Philadelphia   40.0247   -75.0518
# 29       19136  Philadelphia   40.0422   -75.0244
# 30       19137  Philadelphia   40.0008   -75.0727
# 31       19138  Philadelphia   40.0568   -75.1569
# 32       19139  Philadelphia   39.9612   -75.2303
# 33       19140  Philadelphia   40.0118   -75.1456
# 34       19141  Philadelphia   40.0365   -75.1451
# 35       19142  Philadelphia   39.9223   -75.2338
# 36       19143  Philadelphia   39.9448   -75.2288
# 37       19144  Philadelphia   40.0338   -75.1731
# 38       19145  Philadelphia   39.9227   -75.1812
# 39       19146  Philadelphia   39.9379   -75.1794
# 40       19147  Philadelphia   39.9362   -75.1563
# 41       19148  Philadelphia   39.9207   -75.1595
# 42       19149  Philadelphia   40.0369   -75.0664
# 43       19150  Philadelphia   40.0726   -75.1706
# 44       19151  Philadelphia   39.9772   -75.2545
# 45       19152  Philadelphia   40.0606   -75.0471
# 46       19153  Philadelphia   39.9055   -75.2444
# 47       19154  Philadelphia   40.0897   -74.9781
#
#                         neighbourhood
# 0                  Rittenhouse Square
# 1                  Rittenhouse Square
# 2                    Powelton Village
# 3                        Society Hill
# 4                  Rittenhouse Square
# 5                  Rittenhouse Square
# 6                            Burholme
# 7                  South Philadelphia
# 8                      Academy Garden
# 9                           Pauls Run
# 10                           Somerton
# 11                            Gravers
# 12                     Mount Pleasant
# 13                              Olney
# 15                             Ludlow
# 16                             Poplar
# 17                          Northwood
# 18                           Fishtown
# 19                          Pittville
# 20                        Glen Willow
# 21                         Roxborough
# 22                         East Falls
# 23                      Spring Garden
# 24                           Parkside
# 25                            Stanton
# 26                    West Kensington
# 27  Port Richmond Polish Neighborhood
# 28                        Wissinoming
# 29                         Holmesburg
# 30                         Bridesburg
# 31                         Somerville
# 32                       Garden Court
# 33                       Hunting Park
# 34                              Tabor
# 35                           Paschall
# 36                         Cedar Park
# 37                     Wayne Junction
# 38                     Girard Estates
# 39                          Hawthorne
# 40                        Bella Vista
# 41                 South Philadelphia
# 42                        Wissinoming
# 43                            Mermaid
# 44                          Overbrook
# 45                     Pennypack Park
# 46                           Eastwick
# 47                     Longmead Farms

# %% [markdown]
# ## And Finally Foursquare API data to get description and location of venues

# %%
#Obtain all categories for venue types and their IDs to fine tune our venue search to only include our selected features.

CLIENT_ID = '10UP2LT2HSBHAECSOXEODQS4RMO2DYHNMJTRWFBR2Z2REVLK' # your Foursquare ID
CLIENT_SECRET = 'OVV3FEQZE2Z4TEOJ2KCHCD24PJKXGXRAU15ZIIHE4TBIJYZL' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version
getCategoriesURL = 'https://api.foursquare.com/v2/venues/categories?&client_id={}&client_secret={}&v={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET,
            VERSION)
resultsCategories = requests.get(getCategoriesURL)
categories = resultsCategories.json()["response"]['categories']
# print(categories)
for each in categories:
    print(each['name'],each['id'])
# Out:
# Arts & Entertainment 4d4b7104d754a06370d81259
# College & University 4d4b7105d754a06372d81259
# Event 4d4b7105d754a06373d81259
# Food 4d4b7105d754a06374d81259
# Nightlife Spot 4d4b7105d754a06376d81259
# Outdoors & Recreation 4d4b7105d754a06377d81259
# Professional & Other Places 4d4b7105d754a06375d81259
# Residence 4e67e38e036454776db1fb3a
# Shop & Service 4d4b7105d754a06378d81259
# Travel & Transport 4d4b7105d754a06379d81259

# %%
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)

eligibleUniversityVenues = '4d4b7105d754a06372d81259'

eligibleFoodVenues = '4d4b7105d754a06374d81259'

eligibleTransportVenues = '4d4b7105d754a06379d81259'

def getNearbyVenues(names, latitudes, longitudes, radius, categoryString):
    LIMIT = 100
    venues_list=[]
    getCategoriesURL = 'https://api.foursquare.com/v2/venues/categories?&client_id={}&client_secret={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET)
    resultsCategories = requests.get(getCategoriesURL)
    for name, lat, lng in zip(names, latitudes, longitudes):
            
        # create the API request URL
        
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}&categoryId={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT,
            categoryString)
            
        # make the GET request
            
        # make the GET request
        try:
            results = requests.get(url).json()["response"]['groups'][0]['items']
        except Exception as e:
            print(e)
            print("\n")
            print(requests.get(url).json()["response"])
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['neighbourhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)


#Get all school, transport and food venues near every postal code

philly_venues_schools = getNearbyVenues(names=phillyData['neighbourhood'],
                                   latitudes=phillyData['latitude'],
                                   longitudes=phillyData['longitude'],
                                    radius=1000,
                                    categoryString=eligibleUniversityVenues 
                                  )

philly_venues_transport = getNearbyVenues(names=phillyData['neighbourhood'],
                                   latitudes=phillyData['latitude'],
                                   longitudes=phillyData['longitude'],
                                          radius=1000,
                                          categoryString=eligibleTransportVenues
                                  )
philly_venues_food = getNearbyVenues(names=phillyData['neighbourhood'],
                                   latitudes=phillyData['latitude'],
                                   longitudes=phillyData['longitude'],
                                    radius=1000,
                                     categoryString=eligibleFoodVenues 
                                  )
# Out:
# Your credentails:
# CLIENT_ID: 10UP2LT2HSBHAECSOXEODQS4RMO2DYHNMJTRWFBR2Z2REVLK
# CLIENT_SECRET:OVV3FEQZE2Z4TEOJ2KCHCD24PJKXGXRAU15ZIIHE4TBIJYZL

# %%
#Count the number of venues for each neighbourhood and put them into seperate dataframes

schools = philly_venues_schools.groupby(['neighbourhood'])['Venue Category'].count().reset_index(name="school_count")
transports = philly_venues_transport.groupby(['neighbourhood'])['Venue Category'].count().reset_index(name="transport_count")
foods = philly_venues_food.groupby(['neighbourhood'])['Venue Category'].count().reset_index(name="food_count")

foods.head()
# Out:
#     neighbourhood  food_count
# 0  Academy Garden          10
# 1     Bella Vista         100
# 2      Bridesburg          12
# 3        Burholme          25
# 4      Cedar Park          29

# %%
#Merge dataframes to obtain specific counts for each type of venue

philly = schools.merge(transports,on="neighbourhood", how='inner')
philly = philly.merge(foods,on="neighbourhood", how='inner')

#Apply weights of 5, 3 and 1 to the school, transport and food counts respectively to normalize the counts.

philly['school_count'] = philly['school_count'] * 5
philly['transport_count'] = philly['transport_count'] * 3
philly['food_count'] = philly['food_count'] * 1
philly['total_score'] = philly['food_count'] + philly['transport_count'] + philly['school_count']

# %%
philly.head()
# Out:
#    Cluster Labels   neighbourhood  school_count  transport_count  food_count  \
# 0               1  Academy Garden            60                3          10
# 1               3     Bella Vista            40              210         100
# 2               1      Bridesburg            25               18          12
# 3               1        Burholme            30               27          25
# 4               5      Cedar Park             5               87          29
#
#    total_score
# 0           73
# 1          350
# 2           55
# 3           82
# 4          121

# %%
# set number of clusters
kclusters = 6
phil = philly
philly_grouped_clustering = philly.drop('neighbourhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(philly_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_
# Out:
# array([1, 3, 1, 1, 5, 1, 1, 5, 5, 5, 5, 1, 3, 1, 5, 1, 4, 1, 5, 1, 1, 1,
#        1, 1, 1, 1, 1, 3, 1, 4, 0, 1, 2, 1, 5, 3, 1, 3, 5, 1, 5],
#       dtype=int32)

# %%
# add clustering labels
philly.insert(0, 'Cluster Labels', kmeans.labels_)

philly_merged = philly.merge(phillyData,on="neighbourhood", how='inner')

# %%
philly_merged
# Out:
#     Cluster Labels                      neighbourhood  school_count  \
# 0                1                     Academy Garden            60
# 1                3                        Bella Vista            40
# 2                1                         Bridesburg            25
# 3                1                           Burholme            30
# 4                5                         Cedar Park             5
# 5                1                         East Falls            50
# 6                1                           Eastwick             5
# 7                5                           Fishtown            50
# 8                5                       Garden Court            50
# 9                5                     Girard Estates            15
# 10               5                        Glen Willow            55
# 11               1                            Gravers            10
# 12               3                          Hawthorne            30
# 13               1                         Holmesburg            20
# 14               5                       Hunting Park            55
# 15               1                     Longmead Farms            30
# 16               4                             Ludlow           455
# 17               1                            Mermaid             5
# 18               5                     Mount Pleasant            50
# 19               1                          Northwood            25
# 20               1                              Olney            20
# 21               1                          Overbrook            25
# 22               1                           Parkside            20
# 23               1                           Paschall            20
# 24               1                          Pauls Run            15
# 25               1                     Pennypack Park            20
# 26               1                          Pittville            25
# 27               3                             Poplar            30
# 28               1  Port Richmond Polish Neighborhood            25
# 29               4                   Powelton Village           450
# 30               0                 Rittenhouse Square          1820
# 31               0                 Rittenhouse Square          1820
# 32               0                 Rittenhouse Square          1820
# 33               0                 Rittenhouse Square          1820
# 34               1                         Roxborough            10
# 35               2                       Society Hill           245
# 36               1                         Somerville            25
# 37               5                 South Philadelphia            20
# 38               5                 South Philadelphia            20
# 39               3                      Spring Garden           190
# 40               1                            Stanton            15
# 41               3                              Tabor           160
# 42               5                     Wayne Junction            30
# 43               1                    West Kensington             5
# 44               5                        Wissinoming            35
# 45               5                        Wissinoming            35
#
#     transport_count  food_count  total_score postal_code   county_name  \
# 0                 3          10           73       19114  Philadelphia
# 1               210         100          350       19147  Philadelphia
# 2                18          12           55       19137  Philadelphia
# 3                27          25           82       19111  Philadelphia
# 4                87          29          121       19143  Philadelphia
# 5                30          27          107       19129  Philadelphia
# 6                36          16           57       19153  Philadelphia
# 7                66          64          180       19125  Philadelphia
# 8               105          40          195       19139  Philadelphia
# 9                87          59          161       19145  Philadelphia
# 10               27          51          133       19127  Philadelphia
# 11               33          33           76       19118  Philadelphia
# 12              168          65          263       19146  Philadelphia
# 13               12          21           53       19136  Philadelphia
# 14               72          47          174       19140  Philadelphia
# 15               15          19           64       19154  Philadelphia
# 16               78          80          613       19122  Philadelphia
# 17               15          22           42       19150  Philadelphia
# 18               54          23          127       19119  Philadelphia
# 19               39          14           78       19124  Philadelphia
# 20               27          31           78       19120  Philadelphia
# 21               15          11           51       19151  Philadelphia
# 22               27          20           67       19131  Philadelphia
# 23               57          32          109       19142  Philadelphia
# 24               18          38           71       19115  Philadelphia
# 25               24          25           69       19152  Philadelphia
# 26               21          21           67       19126    Montgomery
# 27              165         100          295       19123  Philadelphia
# 28               27          35           87       19134  Philadelphia
# 29              183         100          733       19104  Philadelphia
# 30             1200         400         3420       19102  Philadelphia
# 31             1200         400         3420       19103  Philadelphia
# 32             1200         400         3420       19107  Philadelphia
# 33             1200         400         3420       19109  Philadelphia
# 34                6          35           51       19128  Philadelphia
# 35              300         100          645       19106  Philadelphia
# 36               27          37           89       19138  Philadelphia
# 37               87         107          214       19112  Philadelphia
# 38               87         107          214       19148  Philadelphia
# 39              156          74          420       19130  Philadelphia
# 40               45          34           94       19132  Philadelphia
# 41               87          35          282       19141  Philadelphia
# 42               51          43          124       19144  Philadelphia
# 43               45          27           77       19133  Philadelphia
# 44               42          80          157       19135  Philadelphia
# 45               42          80          157       19149  Philadelphia
#
#     latitude  longitude
# 0    40.0634   -74.9990
# 1    39.9362   -75.1563
# 2    40.0008   -75.0727
# 3    40.0596   -75.0818
# 4    39.9448   -75.2288
# 5    40.0118   -75.1861
# 6    39.9055   -75.2444
# 7    39.9788   -75.1262
# 8    39.9612   -75.2303
# 9    39.9227   -75.1812
# 10   40.0275   -75.2242
# 11   40.0723   -75.2034
# 12   39.9379   -75.1794
# 13   40.0422   -75.0244
# 14   40.0118   -75.1456
# 15   40.0897   -74.9781
# 16   39.9780   -75.1459
# 17   40.0726   -75.1706
# 18   40.0547   -75.1866
# 19   40.0178   -75.0895
# 20   40.0343   -75.1213
# 21   39.9772   -75.2545
# 22   39.9845   -75.2282
# 23   39.9223   -75.2338
# 24   40.0903   -75.0410
# 25   40.0606   -75.0471
# 26   40.0568   -75.1379
# 27   39.9660   -75.1510
# 28   39.9925   -75.1133
# 29   39.9597   -75.2024
# 30   39.9489   -75.1661
# 31   39.9513   -75.1741
# 32   39.9487   -75.1593
# 33   39.9496   -75.1637
# 34   40.0402   -75.2231
# 35   39.9474   -75.1473
# 36   40.0568   -75.1569
# 37   39.8893   -75.1782
# 38   39.9207   -75.1595
# 39   39.9677   -75.1735
# 40   39.9954   -75.1698
# 41   40.0365   -75.1451
# 42   40.0338   -75.1731
# 43   39.9925   -75.1415
# 44   40.0247   -75.0518
# 45   40.0369   -75.0664

# %%
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster, totalScore in zip(philly_merged['latitude'], philly_merged['longitude'], philly_merged['neighbourhood'], philly_merged['Cluster Labels'],philly_merged['total_score']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster) + ", Total Score : " + str(totalScore), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
